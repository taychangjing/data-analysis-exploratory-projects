# %% [markdown]
# ## Introduction & Objective

# %% [markdown]
# This dataset provides a comprehensive look at Airbnb prices in London and Paris. London and Paris are both capital cities in Europe. London is the capital of the United Kingdom and Paris is the capital of France. Both are very large, busy cities that are split into different boroughs.It includes information on:
#
# > 1. **City**: Cities in Europe(String)
# > 2. **realSum**: The total price of the Airbnb listing. (Numeric)
# > 3. **Weekdays**: The price of listing either is weekdays or weekends. (Booleon)
# > 4. **room_type**: The type of room being offered (e.g. private, shared, etc.). (Categorical)
# > 5. **room_shared**: Whether the room is shared or not. (Boolean)
# > 6. **room_private**: Whether the room is private or not. (Boolean)
# > 7. **person_capacity**: The maximum number of people that can stay in the room. (Numeric)
# > 8. **host_is_superhost**: Whether the host is a superhost or not. (Boolean)
# > 9. **multi**: Whether the listing is for multiple rooms or not. (Boolean)
# > 10. **biz**: Whether the listing is for business purposes or not. (Boolean)
# > 11. **cleanliness_rating**: The cleanliness rating of the listing. (Numeric)
# > 12. **guest_satisfaction_overall**: The overall guest satisfaction rating of the listing. (Numeric)
# > 13. **bedrooms**: The number of bedrooms in the listing. (Numeric)
# > 14. **dist**: The distance from the city centre. (Numeric)
# > 15. **metro_dist**: The distance from the nearest metro station. (Numeric)
# > 16. **lng**: The longitude of the listing. (Numeric)
# > 17. **lat**: The latitude of the listing. (Numeric)
#
#
# This data set offers insight into how global markets are affected by social dynamics and geographical factors which in turn determine pricing strategies for optimal profitability.

# %% [markdown]
# ## Import libraries

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Dataset

# %%
df_ori= pd.read_csv('dataset/airbnb_lisitng.csv')
df_ori.head()
# Out:
#      City     realSum  Weekdays     room_type  room_shared  room_private  \
# 0  London  103.483149         0   Shared room         True         False
# 1  London  231.896329         0  Private room        False          True
# 2  London  141.818952         0  Private room        False          True
# 3  London  128.883558         0  Private room        False          True
# 4  London  187.210424         0  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0                2              False      0    0                   4
# 1                2              False      0    0                   2
# 2                2              False      0    1                  10
# 3                2              False      0    0                   6
# 4                2              False      1    0                   2
#
#    guest_satisfaction_overall  bedrooms       dist  metro_dist      lng  \
# ...

# %%
df_ori.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16681 entries, 0 to 16680
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   City                        16681 non-null  object
#  1   realSum                     16681 non-null  float64
#  2   Weekdays                    16681 non-null  int64
#  3   room_type                   16681 non-null  object
#  4   room_shared                 16681 non-null  bool
#  5   room_private                16681 non-null  bool
#  6   person_capacity             16681 non-null  int64
#  7   host_is_superhost           16681 non-null  bool
#  8   multi                       16681 non-null  int64
#  9   biz                         16681 non-null  int64
#  10  cleanliness_rating          16681 non-null  int64
#  11  guest_satisfaction_overall  16681 non-null  int64
#  12  bedrooms                    16681 non-null  int64
# ...

# %% [markdown]
# ## Data Wrangling : Standardized Data

# %%
df = df_ori.drop(columns=['lng','lat','room_shared','room_private'])

# %%
df.rename(columns={'realSum': 'price','City':'city','Weekdays':'weekdays'}, inplace=True)
df['price']=df['price'].round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16681 entries, 0 to 16680
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   city                        16681 non-null  object
#  1   price                       16681 non-null  float64
#  2   weekdays                    16681 non-null  int64
#  3   room_type                   16681 non-null  object
#  4   person_capacity             16681 non-null  int64
#  5   host_is_superhost           16681 non-null  bool
#  6   multi                       16681 non-null  int64
#  7   biz                         16681 non-null  int64
#  8   cleanliness_rating          16681 non-null  int64
#  9   guest_satisfaction_overall  16681 non-null  int64
#  10  bedrooms                    16681 non-null  int64
#  11  dist                        16681 non-null  float64
#  12  metro_dist                  16681 non-null  float64
# ...

# %%
df.describe()
# Out:
#               price      weekdays  person_capacity         multi  \
# count  16681.000000  16681.000000     16681.000000  16681.000000
# mean     374.522346      0.464241         2.889275      0.252743
# std      420.975203      0.498735         1.234897      0.434598
# min       54.330000      0.000000         2.000000      0.000000
# 25%      195.030000      0.000000         2.000000      0.000000
# 50%      289.870000      0.000000         2.000000      0.000000
# 75%      447.800000      1.000000         4.000000      1.000000
# max    16445.610000      1.000000         6.000000      1.000000
#
#                 biz  cleanliness_rating  guest_satisfaction_overall  \
# count  16681.000000        16681.000000                16681.000000
# mean       0.330915            9.210539                   91.203705
# std        0.470557            1.094037                   10.536086
# min        0.000000            2.000000                   20.000000
# ...

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# > ## Boxplot

# %% [markdown]
# As our target variable for this dataset is Price, let's check is there any outliers for the target variable.

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# From the boxplot, we can see that there are quite amount of outliers. This may due to the dataset contain of multiple subpopulations with different characteristics such as combining luxury and budget airbnb listing prices. Therefore, we will remove it in order to get a clearer visualization and it may improve the model performance.

# %%
Q1 = df['price'].quantile(0.25)  # 25th percentile (Q1)
Q3 = df['price'].quantile(0.75)  # 75th percentile (Q3)
IQR = Q3 - Q1                    # Interquartile Range (IQR)

# Calculate the exact thresholds
lower_threshold = Q1 - 1.5 * IQR
upper_threshold = Q3 + 1.5 * IQR

lower_threshold, upper_threshold
# Out:
# (np.float64(-184.12500000000003), np.float64(826.955))

# %%
def removal_box_plot(df, column, outliers):
 
    removed_outliers = df[df[column] <= outliers_value]
 
    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers
 
 
outliers_value = 826.955
 
no_outliers = removal_box_plot(df, 'price', outliers_value)

# %% [markdown]
# After we remove the outliers, we will check the correlation of each features against with the target variable.

# %% [markdown]
# > ## Correlation
# Discover the correlation for each features with Price (Target Variable).

# %%
df_corr=df.copy()

# %%
# To remove outliers
df_corr = df_corr[df_corr['price'] <= outliers_value]

# %%
# Convert Category Variable to Numeric Code
df_corr['city'] = df_corr['city'].astype('category').cat.codes

mapper = {'Entire home/apt': 2, 'Private room': 1, 'Shared room': 0}
df_corr['room_type'] = df_corr['room_type'].map(mapper)

# %% [markdown]
# By using mapping method, O = Shared room, 1 = Private room, 2 = Entire home/apt .

# %%
# Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# From the heatmap above, we observed that some of the features against Price have nearly to zero correlation, therefore, we will drop the features for those correlation which are lower than 0.1 as if the correlation is between 0.0 to 0.1, is known as week correalation to no correlation.

# %%
df_corr = df_corr.drop(columns=['weekdays','host_is_superhost','multi','guest_satisfaction_overall','cleanliness_rating'])

# %%
# Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df_corr.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# Before proceed to visualisation, let's see is there any outliers for each features against out target variable.

# %%
def plot_features_against_price(df_corr, target='price'):
    cols = [col for col in df_corr.columns if col not in [target, 'dist', 'metro_dist']]
    plt.figure(figsize=(16, 12))
    
    for i, col in enumerate(cols, start=1):
            plt.subplot(3, 3, i)
            sns.boxplot(x=df_corr[col], y=df_corr[target])
            plt.title(f'{col} vs {target}')
        
    plt.tight_layout()
    plt.show()
plot_features_against_price(df_corr, target='price')

# %% [markdown]
# We can still see there's some outliers for each features against price, it may due to the other features such as distance from city centre and metro station may affect the price too. Therefore, we will not remove it. Now, let's visualize it.

# %%
fig,(ax_1, ax_2, ax_3, ax_6) = plt.subplots(1, 4, figsize=(28, 7))

# 1st Subplot: Average Price by Room Type
sns.barplot(x='room_type', y='price', hue='room_type', data=df, estimator=np.mean, palette='pastel', errorbar=None,ax=ax_1)
ax_1.set_title('Average Price of Airbnb Listing by Room Type')
ax_1.set_xlabel('Types of Room')
ax_1.set_ylabel('Average Price')

# 2nd Subplot: Average Price by Capacity of Person 
sns.barplot(x='person_capacity', y='price',hue='person_capacity', data=df,estimator=np.mean, palette='pastel', errorbar=None, ax=ax_2)
ax_2.set_title('Average Price of Airbnb Listing by Capacity of Person')
ax_2.set_xlabel('Person Capacity')
ax_2.set_ylabel('Average Price')
ax_2.legend().remove()

sns.barplot(x='bedrooms', y='price',hue='bedrooms', data=df,estimator=np.mean, palette='pastel', errorbar=None, ax=ax_3)
ax_3.set_title('Average Price of Airbnb by Number of Bedrooms')
ax_3.set_xlabel('Number of Bedrooms')
ax_3.set_ylabel('Average Price')
ax_3.legend().remove()

sns.barplot(x='biz', y='price',hue='biz', data=df,estimator=np.mean, palette='pastel', errorbar=None, ax=ax_6)
ax_6.set_title('Average Price of Airbnb by Purpose of Airbnb')
ax_6.set_xlabel('Purpose of Airbnb ')
ax_6.set_ylabel('Average Price')
ax_6.legend().remove()
# 0: not for business purpose
# 1: for business purpose

# %% [markdown]
# From the barplot of the average price by the number bedrooms, there is a noticeable trend where the average price increases with the number of bedrooms up to 3 bedrooms. After that, the average price decreases for listings with more than 3 bedrooms.
# Anomaly: The average price for listings with 8 bedrooms is surprisingly low compared to other categories. This could indicate a data anomaly such as the distance of the airbnb from the city centre and metro station. We will visualize it in scatterplot.

# %%
fig,(ax_4,ax_5) = plt.subplots(1, 2, figsize=(20, 8))

# 1st subplot: Price by the Distance of Airbnb from City Centre
sns.scatterplot(data=df_corr, x='dist', y='price', hue="bedrooms",size="bedrooms",palette='pastel', sizes=(20, 200), legend="full",ax=ax_4)
sns.regplot(data=df_corr, x='dist', y='price', scatter=False, ax=ax_4, color='red', logx=True)
ax_4.set_title('Price by Distance of Airbnb Listing from City Centre')
ax_4.set_xlabel('Distance from City Centre')
ax_4.set_ylabel('Price')

# 2nd subplot: Price by the Distance of Airbnb from Metro Station
sns.scatterplot(data=df_corr, x='metro_dist', y='price', hue="bedrooms",size="bedrooms",palette='pastel', sizes=(20, 200), legend="full",ax=ax_5)
sns.regplot(data=df_corr, x='metro_dist', y='price', scatter=False, ax=ax_5, color='red', logx=True)
ax_5.set_title('Price by Distance of Airbnb Listing from Metro Station')
ax_5.set_xlabel('Distance from Metro Station')
ax_5.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# From the scatter plot, there's also few of the outliers. But overall we can see a negative correlation between price with the distance from city centre and metro stattion. Instead, we can also observed that the price of airbnb which have more than 4 bedrooms are lower due to the distance from city centre and metro distance is longer.

# %% [markdown]
# ## Model Development
# We will use df_corr to visualize the dataset as the data types has been converted to integer (numeric code).

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# > ## Function for Plotting

# %%
def DistributionPlot(RedFunction, BlueFunction, RedName, BlueName, Title):
    width = 8
    height = 6
    plt.figure(figsize=(width, height))

    ax4=sns.kdeplot(RedFunction, color="r", label=RedName)
    sns.kdeplot(BlueFunction, color="b", label=BlueName, ax=ax4)
    plt.title(Title)
    plt.legend()
    plt.show()
    plt.close()

# %% [markdown]
# We will use XGB Regressor and Random Forest Regressor to compare the R-squared value and Mean-Squared-Error of the dataset and look at the distribution of the fitted (predicted) values that result from the model and compare it to the distribution of the actual values.
# >  **XGB Regressor** :
# Builds an ensemble of trees sequentially, where each tree attempts to correct the errors of the previous ones. Use Case: Effective for complex datasets with non-linear relationships.

# %%
Z=df_corr.drop(['price'],axis=1)
Y=df_corr['price']
xgb=XGBRegressor()
xgb.fit(Z,Y)
print('The R-square is: ', xgb.score(Z,Y))
Yhat=xgb.predict(Z)
print('The MSE is: ', mean_squared_error(Y, Yhat))
# Out:
# The R-square is:  0.8064226387614731
# The MSE is:  5213.092697197722

# %% [markdown]
# > **Random Forest Regressor** : An ensemble method that fits multiple decision trees on various sub-samples of the dataset and averages the predictions. Reduces overfitting and improves accuracy compared to a single decision tree.

# %%
rfr= RandomForestRegressor()
rfr.fit(Z,Y)
print('The R-square is: ', rfr.score(Z,Y))
yhat=rfr.predict(Z)
print('The MSE is: ', mean_squared_error(Y, Yhat))
# Out:
# The R-square is:  0.9762469061341321
# The MSE is:  5213.092697197722

# %% [markdown]
# Above we can see that from the Random Forest Regressor has a better score of R-squared value (very close to 1). Therefore, we can say that Random Forest Regressor are more suitable to fit the model. Let's visualized the actual and predicted model.

# %%
Title = 'Actual vs Predicted Values for Price'
DistributionPlot(Y, yhat, 'Actual Values', 'Predicted Values', Title)

# %% [markdown]
# The predicted model can be seen that is closely fit to the actual model, therefore, we will not perform any training for the dataset. Let's see the first 10 predicted values.

# %%
Yhat[0:10]
# Out:
# array([119.186226, 157.02357 , 156.46313 , 181.58064 , 209.48204 ,
#        225.68271 , 258.44492 , 301.2281  , 188.11758 , 638.464   ],
#       dtype=float32)

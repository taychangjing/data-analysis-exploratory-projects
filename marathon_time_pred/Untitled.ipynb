# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dataset/MarathonData.csv')
df
# Out:
#     id  Marathon              Name Category  km4week    sp4week CrossTraining  \
# 0    1  Prague17      Blair MORGAN      MAM    132.8  14.434783           NaN
# 1    2  Prague17     Robert Heczko      MAM     68.6  13.674419           NaN
# 2    3  Prague17     Michon Jerome      MAM     82.7  13.520436           NaN
# 3    4  Prague17     Daniel Or lek      M45    137.5  12.258544           NaN
# 4    5  Prague17      Luk ? Mr zek      MAM     84.6  13.945055           NaN
# ..  ..       ...               ...      ...      ...        ...           ...
# 82  83  Prague17  Stefano Vegliani      M55     50.0  10.830325           NaN
# 83  84  Prague17    Andrej Madliak      M40     33.6  10.130653   ciclista 3h
# 84  85  Prague17        Yoi Ohsako      M40     55.4  11.043189           NaN
# 85  86  Prague17        Simon Dunn      M45     33.2  11.066667           NaN
# 86  87  Prague17       Pavel ?imek      M40     17.9  10.848485   ciclista 5h
#
#    Wall21  MarathonTime CATEGORY
# 0    1.16          2.37        A
# 1    1.23          2.59        A
# 2    1.30          2.66        A
# 3    1.32          2.68        A
# 4    1.36          2.74        A
# ..    ...           ...      ...
# 82   2.02          3.93        D
# 83   1.94          3.93        D
# 84   1.94          3.94        D
# 85   2.05          3.95        D
# 86   2.05          3.98        D
#
# [87 rows x 10 columns]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             87 non-null     int64
#  1   Marathon       87 non-null     object
#  2   Name           87 non-null     object
#  3   Category       81 non-null     object
#  4   km4week        87 non-null     float64
#  5   sp4week        87 non-null     float64
#  6   CrossTraining  13 non-null     object
#  7   Wall21         87 non-null     object
#  8   MarathonTime   87 non-null     float64
#  9   CATEGORY       87 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 6.9+ KB
#               id     km4week       sp4week  MarathonTime
# count  87.000000   87.000000     87.000000     87.000000
# mean   44.000000   62.347126    139.840706      3.319080
# std    25.258662   26.956019   1191.427864      0.376923
# min     1.000000   17.900000      8.031414      2.370000
# 25%    22.500000   44.200000     11.498168      3.045000
# 50%    44.000000   58.800000     12.163424      3.320000
# 75%    65.500000   77.500000     12.854036      3.605000
# max    87.000000  137.500000  11125.000000      3.980000

# %%
df.drop(df[['id','Marathon','Name','CrossTraining']], axis=1,inplace=True)
df
# Out:
#    Category  km4week    sp4week Wall21  MarathonTime CATEGORY
# 0       MAM    132.8  14.434783   1.16          2.37        A
# 1       MAM     68.6  13.674419   1.23          2.59        A
# 2       MAM     82.7  13.520436   1.30          2.66        A
# 3       M45    137.5  12.258544   1.32          2.68        A
# 4       MAM     84.6  13.945055   1.36          2.74        A
# ..      ...      ...        ...    ...           ...      ...
# 82      M55     50.0  10.830325   2.02          3.93        D
# 83      M40     33.6  10.130653   1.94          3.93        D
# 84      M40     55.4  11.043189   1.94          3.94        D
# 85      M45     33.2  11.066667   2.05          3.95        D
# 86      M40     17.9  10.848485   2.05          3.98        D
#
# [87 rows x 6 columns]

# %%
df.replace({'Wall21': {' -   ': np.nan}}, inplace=True)
df.dropna(subset=['Wall21'], axis=0,inplace=True)
df['Wall21']=df['Wall21'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81 entries, 0 to 86
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      81 non-null     object
#  1   km4week       81 non-null     float64
#  2   sp4week       81 non-null     float64
#  3   Wall21        81 non-null     float64
#  4   MarathonTime  81 non-null     float64
#  5   CATEGORY      81 non-null     object
# dtypes: float64(4), object(2)
# memory usage: 4.4+ KB

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Category', data=df, palette= 'pastel')
plt.title('Distribution of Marathon Category(Sex & Age)')
plt.ylabel('Count')
plt.show()
# Out:
# /var/folders/6_/9cjknwbj6n5dbp5d36yy_jzr0000gn/T/ipykernel_17583/895680120.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Category', data=df, palette= 'pastel')

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='CATEGORY', data=df, palette= 'pastel')
plt.title('Distribution of Marathon Category(Total Time)')
plt.ylabel('Count')
plt.show()
# Out:
# /var/folders/6_/9cjknwbj6n5dbp5d36yy_jzr0000gn/T/ipykernel_17583/436167279.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='CATEGORY', data=df, palette= 'pastel')

# %%
y=df['MarathonTime']
x=df['Wall21']
plt.scatter(x,y)
plt.xlabel('Wall21')
plt.ylabel('MarathonTime')
